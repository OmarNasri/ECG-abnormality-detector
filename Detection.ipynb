# %% [markdown]
# Dataset from: https://www.kaggle.com/datasets/shayanfazeli/heartbeat?resource=download

# %%
import pandas as pd 
import matplotlib.pyplot as plt

ecg_data = pd.read_csv('ecg_train.csv', header=None)
print(ecg_data.shape)

#plot the first sample
plt.plot(ecg_data.iloc[0,0:188])
plt.show()
# Out:
# (2000, 188)
