# %% [markdown]
# Dataset from: https://www.kaggle.com/datasets/shayanfazeli/heartbeat?resource=download
#
# Jos rivin viimenen arvo = 1, on kyseessä epänormaali syke.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

ecg_data = pd.read_csv('ecg_normal.csv', header=None)
print(ecg_data.shape)

#plot the first sample
plt.plot(ecg_data.iloc[2,0:188])
plt.show()
# Out:
# (2000, 188)
