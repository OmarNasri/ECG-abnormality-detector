# %%
#imports
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ecg_data = pd.read_csv('normal\\sample_ID100_0.csv', header=None, sep='\t', skiprows=1)
print(ecg_data.shape)

#plotting
plt.figure(figsize=(10,5))
plt.plot(ecg_data[0])
plt.show()
# Out:
# (3600, 1)
